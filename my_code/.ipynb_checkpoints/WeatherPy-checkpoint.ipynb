# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
#     Perform a weather check on each city using a series of successive API calls.
#     Include a print log of each city as it's being processed (with the city number and city name).

# %%
ncities = []
cloudiness = []
Country = []
date = []
Humidity = []
temp = []
Lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print(f'Processing record {record_counter} of set {set_counter} | {city}')
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        Lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        ncities.append(city)
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 0 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 0 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 0 | yara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 0 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 0 | slave lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 0 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 0 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 11 of set 0 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 0 | tsienyane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 13 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 0 | velsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 0 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 0 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 0 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 0 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 0 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 0 | dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 0 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 0 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 0 | sovetskaya gavan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 0 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 0 | pahalgam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 0 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 36 of set 0 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 0 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 40 of set 0 | suihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 0 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 0 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 1 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 2 of set 1 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 1 | priiskovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 1 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 1 | folldal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 1 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 1 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 1 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 1 | lieksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 1 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 1 | ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 1 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 1 | tiruvottiyur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 29 of set 1 | gazimurskiy zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 1 | las vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 1 | tansen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 36 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 1 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 1 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 1 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 1 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 1 | galiwinku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 46 of set 1 | iwade
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 1 | carinhanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 2 | leninskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 2 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 2 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 2 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 2 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 2 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 14 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 16 of set 2 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 2 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 19 of set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 2 | fort frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 2 | reykjavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 2 | adra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 2 | bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 2 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 2 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 2 | wana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 2 | cristalina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 2 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 2 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 2 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 36 of set 2 | winslow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 2 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 2 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 2 | elvas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 2 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 2 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 2 | agadir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 2 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 2 | paradwip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 49 of set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 50 of set 2 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 3 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 3 | odweyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 3 | lang son
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 3 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 3 | belomorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 3 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 7 of set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 3 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 3 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 3 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 3 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 3 | bethanien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 3 | karimnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 3 | mendi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 3 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 3 | safranbolu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 3 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 3 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 3 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 3 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 3 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 3 | ystad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 3 | braslav
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 31 of set 3 | kon tum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 3 | bajil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 3 | pasighat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 3 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 36 of set 3 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 37 of set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 3 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 3 | shepetivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 3 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 3 | bagotville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 3 | catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 3 | dhanbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 3 | galgani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 45 of set 3 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 3 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 3 | fengzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 4 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 4 | sandpoint
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 4 | aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 4 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 4 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 6 of set 4 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 4 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 4 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 4 | rudbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 4 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 4 | frontera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 4 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 4 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 15 of set 4 | nerchinskiy zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 4 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 18 of set 4 | mandurah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 4 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 4 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 4 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 4 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 4 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 4 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 4 | ust-shonosha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 4 | maturin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 4 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 4 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 4 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 4 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 4 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 36 of set 4 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 4 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 4 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 4 | bogatoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 4 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 4 | umm durman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 42 of set 4 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 4 | marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 4 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 46 of set 4 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 47 of set 4 | beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 4 | prainha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 4 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 5 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 5 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 5 | male
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 5 | tignere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 5 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 5 | kodinar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 5 | faro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 5 | altar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 5 | dno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 5 | bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 5 | devils lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 5 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 5 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 5 | poshekhonye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 5 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 5 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 5 | severomuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 5 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 5 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 5 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 5 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 5 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 5 | churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 5 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 5 | fayaoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 5 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 5 | harpalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 5 | hvammstangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 32 of set 5 | venice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 5 | groningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 5 | aquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 5 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 36 of set 5 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 5 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 5 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 5 | los angeles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 5 | ermelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 5 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 5 | ajaccio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 5 | arnstadt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 5 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 5 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 5 | yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 5 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 5 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 6 | phuket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 6 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 3 of set 6 | biu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 6 | barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 6 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 6 | bristol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 6 | kantunilkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 6 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 6 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 10 of set 6 | butterworth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 6 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 6 | gidole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 6 | la trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 6 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 6 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 6 | devin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 6 | sofiysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 20 of set 6 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 6 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 6 | yanchukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 23 of set 6 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 6 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 6 | glenwood springs
# ...
# Processing record 48 of set 9 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 9 | zhongshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 9 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 10 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 1 of set 10 | dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 2 of set 10 | fagersta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 10 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 10 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 5 of set 10 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 6 of set 10 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 10 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 10 | inongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 10 | shelbyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 10 | kologriv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 10 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 10 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 10 | elban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 10 | austin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 10 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 10 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 10 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 10 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 10 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 10 | diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 10 | tapaua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 22 of set 10 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 10 | vagur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 10 | bhadasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 10 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 10 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 10 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 10 | tottori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 10 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 10 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 10 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 10 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 33 of set 10 | manuk mangkaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 10 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 10 | riaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 36 of set 10 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 10 | waw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 10 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 10 | baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 10 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 10 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 10 | conceicao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 10 | wad madani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 10 | zinder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 10 | chunoyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 10 | north platte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 10 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 48 of set 10 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 10 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 50 of set 10 | haikou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 11 | golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 11 | yunjinghong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 2 of set 11 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 11 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 4 of set 11 | ijaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 5 of set 11 | saravena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 6 of set 11 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 7 of set 11 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 8 of set 11 | woodward
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 9 of set 11 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 10 of set 11 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 11 of set 11 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 12 of set 11 | camocim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 13 of set 11 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 14 of set 11 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 15 of set 11 | srikakulam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 16 of set 11 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 17 of set 11 | kargil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 18 of set 11 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 19 of set 11 | severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 20 of set 11 | tygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 21 of set 11 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 22 of set 11 | ayorou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 23 of set 11 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 24 of set 11 | ekpoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 25 of set 11 | mutare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 26 of set 11 | rajgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 27 of set 11 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 28 of set 11 | gouyave
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 29 of set 11 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 30 of set 11 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 31 of set 11 | tacarigua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 32 of set 11 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 33 of set 11 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 34 of set 11 | nueva concepcion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 35 of set 11 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 36 of set 11 | dabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 37 of set 11 | ejura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 38 of set 11 | bati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 39 of set 11 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 40 of set 11 | sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 41 of set 11 | angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 42 of set 11 | fomboni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 43 of set 11 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 44 of set 11 | tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 45 of set 11 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 46 of set 11 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 47 of set 11 | zhaoyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 48 of set 11 | suleja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 49 of set 11 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 50 of set 11 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 0 of set 12 | jiangdu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 1 of set 12 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# City not found. Skipping...
# Processing record 2 of set 12 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# Processing record 3 of set 12 | san ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b3f05fa310fbdebca3b8b87b06abbe
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame.
#      Export the city data into a .csv.
#      Display the DataFrame

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dictionary = {
    "City": ncities,
    "Cloudiness (%)" : cloudiness,
    "Country" : Country,
    "Date" : date,
    "Humidity (%)" : Humidity,
    "Lat" : Lat,
    "Lng" : lng,  
    "Max Temperature (F)": temp,
    "Wind Speed (mph)" : wind
}
weather_df = pd.DataFrame(weather_dictionary)
weather_df.count()
# Out:
# City                   559
# Cloudiness (%)         559
# Country                559
# Date                   559
# Humidity (%)           559
# Lat                    559
# Lng                    559
# Max Temperature (F)    559
# Wind Speed (mph)       559
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 0  severo-kurilsk              85      RU  1586295568            92  50.68
# 1         gigmoto               2      PH  1586295569            74  13.78
# 2  saint-philippe              75      RE  1586295569            83 -21.36
# 3            yara               3      CU  1586295569            38  20.28
# 4         rikitea              53      PF  1586295569            82 -23.12
#
#       Lng  Max Temperature (F)  Wind Speed (mph)
# 0  156.12                32.97             29.71
# 1  124.39                80.42              4.63
# 2   55.77                75.20              2.24
# 3  -76.95                92.71              4.05
# 4 -134.97                77.07             12.97

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
x_values =weather_df["Lat"] 
y_values =weather_df["Max Temperature (F)"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (12/12/2019)")
plt.grid()
# Show Plot and save as .png
plt.show
plt.savefig("Lat_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_values =weather_df["Lat"] 
y_values =weather_df["Humidity (%)"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (12/12/2019)")
plt.grid()
# Show Plot and save as .png
plt.show
plt.savefig("Lat_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values =weather_df["Lat"] 
y_values =weather_df["Cloudiness (%)"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (12/12/2019)")
plt.grid()
# Show Plot and save as .png
plt.show
plt.savefig("Lat_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values =weather_df["Lat"] 
y_values =weather_df["Wind Speed (mph)"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (12/12/2019)")
plt.grid()
# Show Plot and save as .png
plt.show
plt.savefig("Lat_Wind_Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = weather_df[weather_df["Lng"]>0]
southern_df = weather_df[weather_df["Lng"]<0]
southern_df
# Out:
#                City  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 3              yara               3      CU  1586295569            38  20.28
# 4           rikitea              53      PF  1586295569            82 -23.12
# 5      san patricio               5      MX  1586295569            69  19.22
# 6        slave lake              90      CA  1586295569            76  55.28
# 7    vestmannaeyjar              67      IS  1586295569            75  63.44
# ..              ...             ...     ...         ...           ...    ...
# 548     grand-santi             100      GF  1586295643            90   4.25
# 550         hualmay               2      PE  1586295643            67 -11.10
# 554          touros               3      BR  1586295644            74  -5.20
# 555           paita              37      PE  1586295644            65  -5.09
# 558       san ramon              75      US  1586295644            51  37.78
#
#         Lng  Max Temperature (F)  Wind Speed (mph)
# 3    -76.95                92.71              4.05
# 4   -134.97                77.07             12.97
# 5   -104.70                80.60              9.17
# 6   -114.77                32.00             23.04
# 7    -20.27                38.30             14.54
# ..      ...                  ...               ...
# 548  -54.38                79.56              3.58
# 550  -77.61                77.18              8.25
# 554  -35.46                82.40             11.41
# 555  -81.11                79.02             13.53
# 558 -121.98                66.99              3.36
#
# [227 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on Max Temperature vs. Latitude
x_values =northern_df["Lat"] 
y_values =northern_df["Max Temperature (F)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern City Latitude vs. Max Temperature (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,10),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("Nothern_Lat_Temperature.png")
# Out:
# Here is the regression line y = -0.44x +65.49

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on Max Temperature vs. Latitude
x_values =southern_df["Lat"] 
y_values =southern_df["Max Temperature (F)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern City Latitude vs. Max Temperature (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(-.25,15),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("southern_Lat_Temperature.png")
# Out:
# Here is the regression line y = -0.44x +73.64

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Humidity vs. Latitude
x_values =northern_df["Lat"] 
y_values =northern_df["Humidity (%)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern City Latitude vs. Humidity (12/12/2019)")
plt.grid()
plt.annotate(line_eq,(.2,10),fontsize=15,color="red")
# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")

# Show Plot and save as .png
plt.show
plt.savefig("Nothern_Lat_Humidity.png")
# Out:
# Here is the regression line y = 0.06x +68.45

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Humidity vs. Latitude
x_values =southern_df["Lat"] 
y_values =southern_df["Humidity (%)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern City Latitude vs. Humidity (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,10),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("southern_Lat_Humidity.png")
# Out:
# Here is the regression line y = 0.05x +61.8

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Cloudiness  vs. Latitude
x_values =northern_df["Lat"] 
y_values =northern_df["Cloudiness (%)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern City Latitude vs. Cloudiness(12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,10),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("Nothern_Lat_Cloudiness.png")
# Out:
# Here is the regression line y = -0.02x +47.29

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Cloudiness (%) vs. Latitude
x_values =southern_df["Lat"] 
y_values =southern_df["Cloudiness (%)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern City Latitude vs. Cloudiness (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,10),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("southern_Lat_Cloudiness.png")
# Out:
# Here is the regression line y = 0.04x +43.16

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Wind Speed  vs. Latitude
x_values =northern_df["Lat"] 
y_values =northern_df["Wind Speed (mph)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern City Latitude vs. Wind Speed (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,25),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("Nothern_Lat_Wind_Speed .png")
# Out:
# Here is the regression line y = 0.02x +7.17

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Wind Speed (mph) vs. Latitude
x_values =southern_df["Lat"] 
y_values =southern_df["Wind Speed (mph)"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regression_values = x_values * slope + intercept 

# Scatter plot and regression line
plt.scatter(x_values,y_values)

plt.plot(x_values,regression_values, color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern City Latitude vs. Wind Speed (12/12/2019)")
plt.grid()

# Create regression line equation string,  
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Here is the regression line {line_eq}")
plt.annotate(line_eq,(.2,25),fontsize=15,color="red")
# Show Plot and save as .png
plt.show
plt.savefig("southern_Lat_Wind_Speed.png")
# Out:
# Here is the regression line y = 0.03x +9.55
